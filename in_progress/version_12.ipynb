# %%
from keras import layers
from keras import models
from keras import optimizers
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
from numpy import random
import os
from os.path import isfile, join
import pandas as pd
from math import ceil
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
class ConvnetSneakers:
    def __init__(self, base_image_path, master_image_size, master_color_channels):
        self.master_image_size = master_image_size
        self.base_image_path = base_image_path
        self.master_color_channels = master_color_channels
    
    def get_new_model(self):
        """
        Creates a new CNN model. It also prints a summary of the
        model.

        It uses the external variables master_image_size and
        master_color_channels to setup the input layer.

        Returns
        -------
        keras.models.Sequential
            The model ready to be trained
        """
        model = models.Sequential()
        model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(self.master_image_size[0],
                                                                            self.master_image_size[1],
                                                                            self.master_color_channels)))
        model.add(layers.MaxPooling2D((2, 2)))
        model.add(layers.Conv2D(64, (3, 3), activation='relu'))
        model.add(layers.MaxPooling2D((2, 2)))
        model.add(layers.Conv2D(64, (3, 3), activation='relu'))
        model.add(layers.MaxPooling2D((2, 2)))
        model.add(layers.Conv2D(64, (3, 3), activation='relu'))
        model.add(layers.MaxPooling2D((2, 2)))
        model.add(layers.Conv2D(64, (3, 3), activation='relu'))
        model.add(layers.MaxPooling2D((2, 2)))
        model.add(layers.Flatten())
        model.add(layers.Dense(256, activation='relu'))
        model.add(layers.Dense(1, activation='sigmoid'))
        model.compile(loss='binary_crossentropy', optimizer=optimizers.RMSprop(lr=0.5e-4), metrics=['acc'])

        model.summary()

        return model
    
    def train_validation_test(self, shuffle_seed=0):
        """
        Reads images in a directory and splits them up according to class

        Assumes a binary classification, with EQUAL COUNTS in each
        class.

        This automatically assigns classes to the images. It assumes
        the name of each class is the first token of the filename as
        delimited by "_".

        The dataframes returned are to be used by Keras. They have the
        columns "filename" and "class" to point to the images and the
        classes, repectively.

        Parameters
        ----------
        shuffle_seed : int
            The integer to seed the random number generator which shuffles
            the dataframe.

        Returns
        -------
        pd.DataFrame, pd.DataFrame, pd.DataFrame
            The train, validation and test sets, respectively.
        """
        train_fraction = 0.8
        random.seed(shuffle_seed)

        all_images_list = []

        for filename in os.listdir(self.base_image_path):
            if isfile(join(self.base_image_path, filename)):
                image_class = filename.split('.')[0]
                all_images_list.append({'class': image_class, 'filename': filename})

        all_images = pd.DataFrame(all_images_list)
        all_images = all_images.sample(frac=1).reset_index(drop=True)
        all_classes = all_images['class'].unique()

        first_class_name = all_classes[0]
        second_class_name = all_classes[1]

        first_class = all_images.copy().where(all_images['class'] == first_class_name).dropna()
        second_class = all_images.copy().where(all_images['class'] == second_class_name).dropna()

        train_row_count = int(len(first_class) * train_fraction)
        test_val_count = len(first_class) - train_row_count

        first_class_train = first_class.iloc[2 * test_val_count:]
        first_class_val = first_class.iloc[test_val_count:2 * test_val_count]
        first_class_test = first_class.iloc[0:test_val_count]

        second_class_train = second_class.iloc[2 * test_val_count:]
        second_class_val = second_class.iloc[test_val_count:2 * test_val_count]
        second_class_test = second_class.iloc[0:test_val_count]

        train = first_class_train.append(second_class_train).reset_index().drop('index', axis=1)
        val = first_class_val.append(second_class_val).reset_index().drop('index', axis=1)
        test = first_class_test.append(second_class_test).reset_index().drop('index', axis=1)

        return train, val, test
    
    def train_validation_test_generators(self, shuffle_seed=0):
        """
        Creates generators for train, validation and test datasets. These
        can then be used by Keras to train a model.

        Dataframe shuffling is prevented at this step because the dataframe
        is assumed to have been shuffled beforehand with an RNG with a known
        seed.

        The dataframe is created for you from the images in src_dir. See the
        train_validation_test function for more information.

        Parameters
        ----------
        shuffle_seed : int
            The seed for the RNG used for dataframe shuffling.

        Returns
        -------
        """
        train, validation, test = self.train_validation_test(shuffle_seed)

        train_datagen = image.ImageDataGenerator(rescale=1.0/255)
        test_datagen = image.ImageDataGenerator(rescale=1.0/255)
        validation_datagen = image.ImageDataGenerator(rescale=1.0/255)

        train_generator = train_datagen.flow_from_dataframe(dataframe=train,
                                                            directory=self.base_image_path,
                                                            target_size=self.master_image_size,
                                                            batch_size=20,
                                                            shuffle=False,
                                                            color_mode='grayscale',
                                                            class_mode='binary')

        validation_generator = train_datagen.flow_from_dataframe(dataframe=validation,
                                                          directory=self.base_image_path,
                                                          target_size=self.master_image_size,
                                                          batch_size=20,
                                                          shuffle=False,
                                                          color_mode='grayscale',
                                                          class_mode='binary')

        test_generator = train_datagen.flow_from_dataframe(dataframe=test,
                                                           directory=self.base_image_path,
                                                           target_size=self.master_image_size,
                                                           batch_size=20,
                                                           shuffle=False,
                                                           color_mode='grayscale',
                                                           class_mode='binary')

        return train_generator, validation_generator, test_generator
    
    def train_model_and_get_history(self, shuffle_seed=0, epochs=10):
        """
        Trains a model and returns the RNG seed and history

        Parameters
        ----------
        shuffle_seed : int
            The seed for the RNG that shuffles the train, validation
            and test datasets.

        Returns
        -------
        keras.model.Sequential, dict
            The model that created the history
        """
        train_generator, validation_generator, test_generator = self.train_validation_test_generators(shuffle_seed)
        model = self.get_new_model()
        train_history = model.fit_generator(train_generator,
                                            steps_per_epoch=100,
                                            epochs=epochs,
                                            validation_data=validation_generator,
                                            validation_steps=50,
                                            verbose=1)
        return model, train_history
    
    def train_and_run_different_shuffles(self, shuffles=10, epochs_per_shuffle=10):
        """
        This runs a sequence of trainings, each with a different shuffle
        controlled by a different random number generator.
        
        Parameters
        ----------
        shuffles : int
            The number of shuffles and training runs to go.
            
        epochs_per_shuffle : int
            The number of epochs in each shuffle of the data.
            
        Returns
        -------
        list, list
            List of histories (see below) of the training runs and a list
            of the maximum validation accuracies for each training run.
        """
        histories = []
        max_val_accs = []
        for shuffle_seed in range(shuffles):
            print(f'>>> Shuffle seed {shuffle_seed}')
            model, history = self.train_model_and_get_history(shuffle_seed, epochs=epochs_per_shuffle)
            train, validation, test = self.train_validation_test(shuffle_seed)
            histories.append({
                'shuffle_seed': shuffle_seed,
                'epochs': epochs_per_shuffle,
                'val_accs': history.history['val_acc'],
                'max_val_acc': max(history.history['val_acc']),
                'model': model,
                'train': train,
                'validation': validation,
                'test': test
            })
            max_val_accs.append(max(history.history['val_acc']))
        return histories, max_val_accs

# %%
trainer = ConvnetSneakers(master_image_size=(256, 256), base_image_path='grayscale-256x256', master_color_channels=1)
histories, max_val_accs = trainer.train_and_run_different_shuffles(shuffles=50, epochs_per_shuffle=13)
# Out:
# >>> Shuffle seed 0
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# WARNING:tensorflow:From /home/alicia/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               590080
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /home/alicia/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/13
# 100/100 [==============================] - 15s 148ms/step - loss: 0.6974 - acc: 0.4492 - val_loss: 0.6926 - val_acc: 0.5122
# Epoch 2/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6942 - acc: 0.5102 - val_loss: 0.6911 - val_acc: 0.6341
# Epoch 3/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6881 - acc: 0.5707 - val_loss: 0.6906 - val_acc: 0.5000
# Epoch 4/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6800 - acc: 0.5948 - val_loss: 0.6810 - val_acc: 0.5366
# Epoch 5/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6552 - acc: 0.6463 - val_loss: 0.6559 - val_acc: 0.5976
# Epoch 6/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6031 - acc: 0.7081 - val_loss: 0.6224 - val_acc: 0.6463
# Epoch 7/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.5408 - acc: 0.7338 - val_loss: 0.6334 - val_acc: 0.6463
# Epoch 8/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.5062 - acc: 0.7536 - val_loss: 0.6281 - val_acc: 0.6951
# Epoch 9/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4709 - acc: 0.7851 - val_loss: 0.6191 - val_acc: 0.6951
# Epoch 10/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4254 - acc: 0.8104 - val_loss: 0.7096 - val_acc: 0.6220
# Epoch 11/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.3954 - acc: 0.8319 - val_loss: 0.6298 - val_acc: 0.7195
# Epoch 12/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.3450 - acc: 0.8569 - val_loss: 0.6953 - val_acc: 0.6951
# Epoch 13/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.2893 - acc: 0.8754 - val_loss: 0.8475 - val_acc: 0.6463
# >>> Shuffle seed 1
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               590080
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/13
# 100/100 [==============================] - 12s 122ms/step - loss: 0.7013 - acc: 0.4510 - val_loss: 0.6923 - val_acc: 0.5732
# Epoch 2/13
# 100/100 [==============================] - 12s 118ms/step - loss: 0.6950 - acc: 0.4707 - val_loss: 0.6911 - val_acc: 0.6585
# Epoch 3/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6916 - acc: 0.5442 - val_loss: 0.6896 - val_acc: 0.5000
# Epoch 4/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6893 - acc: 0.5443 - val_loss: 0.6810 - val_acc: 0.5000
# Epoch 5/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6784 - acc: 0.6103 - val_loss: 0.6561 - val_acc: 0.7195
# Epoch 6/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6443 - acc: 0.6748 - val_loss: 0.5994 - val_acc: 0.7561
# Epoch 7/13
# 100/100 [==============================] - 12s 117ms/step - loss: 0.5798 - acc: 0.7234 - val_loss: 0.5282 - val_acc: 0.7561
# Epoch 8/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.5241 - acc: 0.7609 - val_loss: 0.4724 - val_acc: 0.7805
# Epoch 9/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4834 - acc: 0.7894 - val_loss: 0.4318 - val_acc: 0.7927
# Epoch 10/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4398 - acc: 0.8074 - val_loss: 0.4747 - val_acc: 0.7561
# Epoch 11/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4088 - acc: 0.8224 - val_loss: 0.4010 - val_acc: 0.8171
# Epoch 12/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.3625 - acc: 0.8489 - val_loss: 0.4311 - val_acc: 0.8415
# Epoch 13/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.3086 - acc: 0.8784 - val_loss: 0.4872 - val_acc: 0.8293
# >>> Shuffle seed 2
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               590080
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/13
# 100/100 [==============================] - 12s 119ms/step - loss: 0.7013 - acc: 0.4573 - val_loss: 0.6928 - val_acc: 0.5000
# Epoch 2/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6948 - acc: 0.4957 - val_loss: 0.6916 - val_acc: 0.5122
# Epoch 3/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6892 - acc: 0.5547 - val_loss: 0.6927 - val_acc: 0.5000
# Epoch 4/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6855 - acc: 0.5453 - val_loss: 0.6860 - val_acc: 0.5000
# Epoch 5/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6684 - acc: 0.5778 - val_loss: 0.6657 - val_acc: 0.6829
# Epoch 6/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6232 - acc: 0.6783 - val_loss: 0.6563 - val_acc: 0.6463
# Epoch 7/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.5597 - acc: 0.7449 - val_loss: 0.6918 - val_acc: 0.6585
# Epoch 8/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.5084 - acc: 0.7729 - val_loss: 0.6469 - val_acc: 0.7561
# Epoch 9/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.4720 - acc: 0.7889 - val_loss: 0.6645 - val_acc: 0.7195
# Epoch 10/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4330 - acc: 0.8219 - val_loss: 0.8519 - val_acc: 0.6829
# Epoch 11/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4090 - acc: 0.8304 - val_loss: 0.6871 - val_acc: 0.7439
# Epoch 12/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.3680 - acc: 0.8394 - val_loss: 0.6881 - val_acc: 0.7683
# Epoch 13/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.3310 - acc: 0.8534 - val_loss: 1.0505 - val_acc: 0.6707
# >>> Shuffle seed 3
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               590080
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/13
# 100/100 [==============================] - 12s 120ms/step - loss: 0.7020 - acc: 0.4734 - val_loss: 0.6928 - val_acc: 0.5000
# Epoch 2/13
# 100/100 [==============================] - 12s 118ms/step - loss: 0.6951 - acc: 0.4652 - val_loss: 0.6919 - val_acc: 0.6341
# Epoch 3/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6920 - acc: 0.5252 - val_loss: 0.6902 - val_acc: 0.5000
# Epoch 4/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6896 - acc: 0.5253 - val_loss: 0.6835 - val_acc: 0.5000
# Epoch 5/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6776 - acc: 0.5793 - val_loss: 0.6671 - val_acc: 0.7073
# Epoch 6/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6458 - acc: 0.6583 - val_loss: 0.6307 - val_acc: 0.6585
# Epoch 7/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.5946 - acc: 0.6948 - val_loss: 0.5922 - val_acc: 0.6707
# Epoch 8/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.5348 - acc: 0.7188 - val_loss: 0.5969 - val_acc: 0.7073
# Epoch 9/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.4858 - acc: 0.7664 - val_loss: 0.5684 - val_acc: 0.7317
# Epoch 10/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4412 - acc: 0.8134 - val_loss: 0.6247 - val_acc: 0.6829
# Epoch 11/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.3974 - acc: 0.8409 - val_loss: 0.6028 - val_acc: 0.7683
# Epoch 12/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.3446 - acc: 0.8649 - val_loss: 0.6873 - val_acc: 0.7439
# Epoch 13/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.2882 - acc: 0.8939 - val_loss: 0.7467 - val_acc: 0.6341
# >>> Shuffle seed 4
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               590080
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/13
# 100/100 [==============================] - 12s 119ms/step - loss: 0.7015 - acc: 0.4672 - val_loss: 0.6927 - val_acc: 0.5000
# Epoch 2/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6952 - acc: 0.4747 - val_loss: 0.6921 - val_acc: 0.5122
# Epoch 3/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6910 - acc: 0.5502 - val_loss: 0.6902 - val_acc: 0.5000
# Epoch 4/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6843 - acc: 0.5908 - val_loss: 0.6820 - val_acc: 0.5976
# Epoch 5/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6586 - acc: 0.6513 - val_loss: 0.6776 - val_acc: 0.5122
# Epoch 6/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6124 - acc: 0.6723 - val_loss: 0.6376 - val_acc: 0.6585
# Epoch 7/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.5437 - acc: 0.7274 - val_loss: 0.6589 - val_acc: 0.6098
# Epoch 8/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4998 - acc: 0.7684 - val_loss: 0.6274 - val_acc: 0.6829
# Epoch 9/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.4710 - acc: 0.7854 - val_loss: 0.6246 - val_acc: 0.7073
# Epoch 10/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4389 - acc: 0.8024 - val_loss: 0.7228 - val_acc: 0.6463
# Epoch 11/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4234 - acc: 0.8164 - val_loss: 0.6335 - val_acc: 0.7073
# Epoch 12/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.3938 - acc: 0.8279 - val_loss: 0.6502 - val_acc: 0.7073
# Epoch 13/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.3587 - acc: 0.8484 - val_loss: 0.8048 - val_acc: 0.6585
# >>> Shuffle seed 5
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_26 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/13
# 100/100 [==============================] - 12s 119ms/step - loss: 0.6996 - acc: 0.4591 - val_loss: 0.6923 - val_acc: 0.5000
# Epoch 2/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6943 - acc: 0.4732 - val_loss: 0.6904 - val_acc: 0.7073
# Epoch 3/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6905 - acc: 0.5602 - val_loss: 0.6863 - val_acc: 0.5000
# Epoch 4/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6848 - acc: 0.5778 - val_loss: 0.6700 - val_acc: 0.6341
# Epoch 5/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6579 - acc: 0.6523 - val_loss: 0.6231 - val_acc: 0.6951
# Epoch 6/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.5969 - acc: 0.7173 - val_loss: 0.5494 - val_acc: 0.7927
# Epoch 7/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.5329 - acc: 0.7604 - val_loss: 0.5282 - val_acc: 0.7805
# Epoch 8/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.4859 - acc: 0.7749 - val_loss: 0.5426 - val_acc: 0.7317
# Epoch 9/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.4527 - acc: 0.7959 - val_loss: 0.5050 - val_acc: 0.7683
# Epoch 10/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4102 - acc: 0.8224 - val_loss: 0.5709 - val_acc: 0.7805
# Epoch 11/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.3716 - acc: 0.8364 - val_loss: 0.4866 - val_acc: 0.8171
# Epoch 12/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.3174 - acc: 0.8574 - val_loss: 0.5766 - val_acc: 0.7561
# Epoch 13/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.2604 - acc: 0.8764 - val_loss: 0.7422 - val_acc: 0.7073
# >>> Shuffle seed 6
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_31 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/13
# 100/100 [==============================] - 12s 119ms/step - loss: 0.6986 - acc: 0.4499 - val_loss: 0.6929 - val_acc: 0.5854
# Epoch 2/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6951 - acc: 0.4982 - val_loss: 0.6925 - val_acc: 0.5000
# Epoch 3/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6912 - acc: 0.5497 - val_loss: 0.6939 - val_acc: 0.5000
# Epoch 4/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6892 - acc: 0.5313 - val_loss: 0.6894 - val_acc: 0.5000
# Epoch 5/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6770 - acc: 0.6013 - val_loss: 0.6755 - val_acc: 0.6098
# Epoch 6/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6366 - acc: 0.6878 - val_loss: 0.6722 - val_acc: 0.6341
# Epoch 7/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.5735 - acc: 0.7299 - val_loss: 0.7339 - val_acc: 0.6341
# Epoch 8/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.5256 - acc: 0.7433 - val_loss: 0.7027 - val_acc: 0.5976
# Epoch 9/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.5000 - acc: 0.7529 - val_loss: 0.7148 - val_acc: 0.6098
# Epoch 10/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.4676 - acc: 0.7659 - val_loss: 0.8713 - val_acc: 0.6220
# Epoch 11/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.4428 - acc: 0.7804 - val_loss: 0.7224 - val_acc: 0.6707
# Epoch 12/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.4093 - acc: 0.8069 - val_loss: 0.7165 - val_acc: 0.6463
# Epoch 13/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.3652 - acc: 0.8364 - val_loss: 1.0016 - val_acc: 0.6220
# >>> Shuffle seed 7
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_36 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/13
# 100/100 [==============================] - 12s 120ms/step - loss: 0.7058 - acc: 0.4539 - val_loss: 0.6928 - val_acc: 0.4756
# Epoch 2/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6960 - acc: 0.4887 - val_loss: 0.6918 - val_acc: 0.5122
# Epoch 3/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6901 - acc: 0.5487 - val_loss: 0.6899 - val_acc: 0.5000
# Epoch 4/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6825 - acc: 0.5743 - val_loss: 0.6762 - val_acc: 0.5610
# Epoch 5/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6520 - acc: 0.6633 - val_loss: 0.6525 - val_acc: 0.6707
# Epoch 6/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.5911 - acc: 0.7248 - val_loss: 0.6094 - val_acc: 0.6098
# Epoch 7/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.5318 - acc: 0.7514 - val_loss: 0.6198 - val_acc: 0.6220
# Epoch 8/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.4924 - acc: 0.7799 - val_loss: 0.6035 - val_acc: 0.7073
# Epoch 9/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.4548 - acc: 0.8034 - val_loss: 0.5844 - val_acc: 0.6707
# Epoch 10/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4107 - acc: 0.8269 - val_loss: 0.6870 - val_acc: 0.6585
# Epoch 11/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.3697 - acc: 0.8424 - val_loss: 0.5669 - val_acc: 0.6707
# Epoch 12/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.3126 - acc: 0.8604 - val_loss: 0.5934 - val_acc: 0.7073
# Epoch 13/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.2508 - acc: 0.8949 - val_loss: 0.8334 - val_acc: 0.6341
# >>> Shuffle seed 8
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_41 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_42 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_43 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_44 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_45 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/13
# 100/100 [==============================] - 12s 121ms/step - loss: 0.7018 - acc: 0.4624 - val_loss: 0.6913 - val_acc: 0.5854
# Epoch 2/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6939 - acc: 0.5197 - val_loss: 0.6892 - val_acc: 0.7195
# Epoch 3/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6877 - acc: 0.5808 - val_loss: 0.6861 - val_acc: 0.5000
# Epoch 4/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6796 - acc: 0.5763 - val_loss: 0.6692 - val_acc: 0.5122
# Epoch 5/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6485 - acc: 0.6478 - val_loss: 0.6286 - val_acc: 0.6829
# Epoch 6/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.5848 - acc: 0.7148 - val_loss: 0.5858 - val_acc: 0.6829
# Epoch 7/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.5336 - acc: 0.7494 - val_loss: 0.6003 - val_acc: 0.6951
# Epoch 8/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.4951 - acc: 0.7714 - val_loss: 0.5532 - val_acc: 0.7317
# Epoch 9/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.4649 - acc: 0.7954 - val_loss: 0.5411 - val_acc: 0.7561
# Epoch 10/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4231 - acc: 0.8044 - val_loss: 0.6521 - val_acc: 0.6463
# Epoch 11/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.3845 - acc: 0.8079 - val_loss: 0.5412 - val_acc: 0.7683
# Epoch 12/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.3359 - acc: 0.8324 - val_loss: 0.5515 - val_acc: 0.7805
# Epoch 13/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.2734 - acc: 0.8734 - val_loss: 0.8592 - val_acc: 0.6220
# >>> Shuffle seed 9
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_46 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_46 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_47 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_50 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/13
# 100/100 [==============================] - 12s 121ms/step - loss: 0.7032 - acc: 0.4773 - val_loss: 0.6925 - val_acc: 0.5000
# Epoch 2/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6949 - acc: 0.4827 - val_loss: 0.6916 - val_acc: 0.5366
# Epoch 3/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6909 - acc: 0.5838 - val_loss: 0.6903 - val_acc: 0.5000
# Epoch 4/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6843 - acc: 0.6398 - val_loss: 0.6813 - val_acc: 0.5732
# Epoch 5/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6603 - acc: 0.6763 - val_loss: 0.6557 - val_acc: 0.6341
# Epoch 6/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6135 - acc: 0.7223 - val_loss: 0.6324 - val_acc: 0.6585
# Epoch 7/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.5575 - acc: 0.7541 - val_loss: 0.6494 - val_acc: 0.5976
# Epoch 8/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.5284 - acc: 0.7751 - val_loss: 0.6011 - val_acc: 0.6707
# Epoch 9/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.4989 - acc: 0.7876 - val_loss: 0.5884 - val_acc: 0.6951
# Epoch 10/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4592 - acc: 0.8218 - val_loss: 0.6958 - val_acc: 0.6463
# Epoch 11/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.4362 - acc: 0.8339 - val_loss: 0.5772 - val_acc: 0.7073
# Epoch 12/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.3963 - acc: 0.8479 - val_loss: 0.5787 - val_acc: 0.6585
# Epoch 13/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.3410 - acc: 0.8784 - val_loss: 0.7784 - val_acc: 0.6585
# >>> Shuffle seed 10
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_51 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_51 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_52 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_53 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_54 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_55 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/13
# 100/100 [==============================] - 12s 121ms/step - loss: 0.6983 - acc: 0.4391 - val_loss: 0.6925 - val_acc: 0.5000
# Epoch 2/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6952 - acc: 0.5032 - val_loss: 0.6912 - val_acc: 0.5000
# Epoch 3/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6915 - acc: 0.5477 - val_loss: 0.6890 - val_acc: 0.5000
# Epoch 4/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6883 - acc: 0.5628 - val_loss: 0.6772 - val_acc: 0.5122
# Epoch 5/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6688 - acc: 0.6098 - val_loss: 0.6419 - val_acc: 0.6829
# Epoch 6/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6212 - acc: 0.6943 - val_loss: 0.5853 - val_acc: 0.7439
# Epoch 7/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.5665 - acc: 0.7304 - val_loss: 0.5591 - val_acc: 0.7439
# Epoch 8/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.5269 - acc: 0.7519 - val_loss: 0.5173 - val_acc: 0.7927
# Epoch 9/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.4858 - acc: 0.7794 - val_loss: 0.4996 - val_acc: 0.7927
# Epoch 10/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4418 - acc: 0.8019 - val_loss: 0.6018 - val_acc: 0.6951
# Epoch 11/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.4048 - acc: 0.8274 - val_loss: 0.4999 - val_acc: 0.7439
# Epoch 12/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.3480 - acc: 0.8459 - val_loss: 0.5258 - val_acc: 0.7317
# Epoch 13/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.2898 - acc: 0.8669 - val_loss: 0.7839 - val_acc: 0.6707
# >>> Shuffle seed 11
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_56 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_56 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_57 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_58 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_59 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_60 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_23 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/13
# 100/100 [==============================] - 12s 122ms/step - loss: 0.7017 - acc: 0.4439 - val_loss: 0.6926 - val_acc: 0.5610
# Epoch 2/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6958 - acc: 0.4712 - val_loss: 0.6919 - val_acc: 0.5732
# Epoch 3/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6929 - acc: 0.5372 - val_loss: 0.6929 - val_acc: 0.5000
# Epoch 4/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6929 - acc: 0.5263 - val_loss: 0.6894 - val_acc: 0.5000
# Epoch 5/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6875 - acc: 0.5607 - val_loss: 0.6807 - val_acc: 0.6220
# Epoch 6/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6685 - acc: 0.6113 - val_loss: 0.6595 - val_acc: 0.6585
# Epoch 7/13
# 100/100 [==============================] - 12s 117ms/step - loss: 0.6261 - acc: 0.6628 - val_loss: 0.6345 - val_acc: 0.6585
# Epoch 8/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.5678 - acc: 0.7238 - val_loss: 0.6154 - val_acc: 0.6463
# ...
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_231 (Conv2D)          (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_231 (MaxPoolin (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_232 (Conv2D)          (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_232 (MaxPoolin (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_233 (Conv2D)          (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_233 (MaxPoolin (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_234 (Conv2D)          (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_234 (MaxPoolin (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_235 (Conv2D)          (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_235 (MaxPoolin (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_47 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_93 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dense_94 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/13
# 100/100 [==============================] - 14s 138ms/step - loss: 0.7060 - acc: 0.4605 - val_loss: 0.6928 - val_acc: 0.5732
# Epoch 2/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6963 - acc: 0.4582 - val_loss: 0.6925 - val_acc: 0.5610
# Epoch 3/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6936 - acc: 0.5222 - val_loss: 0.6929 - val_acc: 0.5000
# Epoch 4/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6926 - acc: 0.5148 - val_loss: 0.6889 - val_acc: 0.5000
# Epoch 5/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6833 - acc: 0.5788 - val_loss: 0.6749 - val_acc: 0.6585
# Epoch 6/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6521 - acc: 0.6568 - val_loss: 0.6398 - val_acc: 0.7195
# Epoch 7/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.5855 - acc: 0.7219 - val_loss: 0.6068 - val_acc: 0.6951
# Epoch 8/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.5179 - acc: 0.7639 - val_loss: 0.5966 - val_acc: 0.6829
# Epoch 9/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.4729 - acc: 0.7719 - val_loss: 0.5672 - val_acc: 0.7073
# Epoch 10/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.4234 - acc: 0.8074 - val_loss: 0.6323 - val_acc: 0.6829
# Epoch 11/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.3793 - acc: 0.8439 - val_loss: 0.5478 - val_acc: 0.7561
# Epoch 12/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.3242 - acc: 0.8664 - val_loss: 0.6595 - val_acc: 0.6829
# Epoch 13/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.2661 - acc: 0.8924 - val_loss: 0.7430 - val_acc: 0.6585
# >>> Shuffle seed 47
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_236 (Conv2D)          (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_236 (MaxPoolin (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_237 (Conv2D)          (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_237 (MaxPoolin (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_238 (Conv2D)          (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_238 (MaxPoolin (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_239 (Conv2D)          (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_239 (MaxPoolin (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_240 (Conv2D)          (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_240 (MaxPoolin (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_48 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_95 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dense_96 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/13
# 100/100 [==============================] - 14s 138ms/step - loss: 0.6998 - acc: 0.4516 - val_loss: 0.6929 - val_acc: 0.5000
# Epoch 2/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6957 - acc: 0.4497 - val_loss: 0.6923 - val_acc: 0.6463
# Epoch 3/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6932 - acc: 0.5217 - val_loss: 0.6916 - val_acc: 0.5000
# Epoch 4/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6921 - acc: 0.5213 - val_loss: 0.6875 - val_acc: 0.5000
# Epoch 5/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6840 - acc: 0.5808 - val_loss: 0.6768 - val_acc: 0.6220
# Epoch 6/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6548 - acc: 0.6678 - val_loss: 0.6416 - val_acc: 0.6463
# Epoch 7/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.5937 - acc: 0.7309 - val_loss: 0.6133 - val_acc: 0.6585
# Epoch 8/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.5325 - acc: 0.7564 - val_loss: 0.6274 - val_acc: 0.6829
# Epoch 9/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.4950 - acc: 0.7854 - val_loss: 0.6041 - val_acc: 0.7073
# Epoch 10/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4621 - acc: 0.7999 - val_loss: 0.6216 - val_acc: 0.7073
# Epoch 11/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.4378 - acc: 0.8059 - val_loss: 0.5962 - val_acc: 0.7195
# Epoch 12/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.3981 - acc: 0.8209 - val_loss: 0.6752 - val_acc: 0.6707
# Epoch 13/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.3627 - acc: 0.8424 - val_loss: 0.6698 - val_acc: 0.7317
# >>> Shuffle seed 48
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_241 (Conv2D)          (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_241 (MaxPoolin (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_242 (Conv2D)          (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_242 (MaxPoolin (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_243 (Conv2D)          (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_243 (MaxPoolin (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_244 (Conv2D)          (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_244 (MaxPoolin (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_245 (Conv2D)          (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_245 (MaxPoolin (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_49 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_97 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dense_98 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/13
# 100/100 [==============================] - 14s 140ms/step - loss: 0.7011 - acc: 0.4750 - val_loss: 0.6927 - val_acc: 0.5000
# Epoch 2/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6951 - acc: 0.4547 - val_loss: 0.6921 - val_acc: 0.6585
# Epoch 3/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6913 - acc: 0.5342 - val_loss: 0.6919 - val_acc: 0.5000
# Epoch 4/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6892 - acc: 0.5298 - val_loss: 0.6870 - val_acc: 0.5000
# Epoch 5/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6787 - acc: 0.5677 - val_loss: 0.6737 - val_acc: 0.6707
# Epoch 6/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6441 - acc: 0.6423 - val_loss: 0.6491 - val_acc: 0.6829
# Epoch 7/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.5855 - acc: 0.6993 - val_loss: 0.6282 - val_acc: 0.6951
# Epoch 8/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.5194 - acc: 0.7433 - val_loss: 0.6326 - val_acc: 0.6341
# Epoch 9/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.4758 - acc: 0.7924 - val_loss: 0.6270 - val_acc: 0.6585
# Epoch 10/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.4404 - acc: 0.8049 - val_loss: 0.6985 - val_acc: 0.6585
# Epoch 11/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.4103 - acc: 0.8319 - val_loss: 0.6492 - val_acc: 0.6585
# Epoch 12/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.3672 - acc: 0.8559 - val_loss: 0.7139 - val_acc: 0.6829
# Epoch 13/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.3320 - acc: 0.8689 - val_loss: 0.8459 - val_acc: 0.6585
# >>> Shuffle seed 49
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_246 (Conv2D)          (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_246 (MaxPoolin (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_247 (Conv2D)          (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_247 (MaxPoolin (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_248 (Conv2D)          (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_248 (MaxPoolin (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_249 (Conv2D)          (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_249 (MaxPoolin (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_250 (Conv2D)          (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_250 (MaxPoolin (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_50 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_99 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dense_100 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/13
# 100/100 [==============================] - 14s 139ms/step - loss: 0.7013 - acc: 0.4339 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 2/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6963 - acc: 0.4732 - val_loss: 0.6927 - val_acc: 0.5000
# Epoch 3/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6932 - acc: 0.5502 - val_loss: 0.6940 - val_acc: 0.5000
# Epoch 4/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6932 - acc: 0.5138 - val_loss: 0.6913 - val_acc: 0.5000
# Epoch 5/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6855 - acc: 0.5547 - val_loss: 0.6852 - val_acc: 0.5610
# Epoch 6/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6569 - acc: 0.6478 - val_loss: 0.6661 - val_acc: 0.5610
# Epoch 7/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.5886 - acc: 0.7299 - val_loss: 0.6700 - val_acc: 0.5732
# Epoch 8/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.5211 - acc: 0.7574 - val_loss: 0.6901 - val_acc: 0.6707
# Epoch 9/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4823 - acc: 0.7674 - val_loss: 0.6805 - val_acc: 0.6463
# Epoch 10/13
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4491 - acc: 0.7844 - val_loss: 0.7767 - val_acc: 0.6829
# Epoch 11/13
# 100/100 [==============================] - 11s 114ms/step - loss: 0.4215 - acc: 0.8054 - val_loss: 0.7110 - val_acc: 0.6951
# Epoch 12/13
# 100/100 [==============================] - 11s 115ms/step - loss: 0.3811 - acc: 0.8339 - val_loss: 0.7638 - val_acc: 0.6341
# Epoch 13/13
# 100/100 [==============================] - 12s 115ms/step - loss: 0.3359 - acc: 0.8494 - val_loss: 0.9038 - val_acc: 0.6220

# %%
max_val_accs
# Out:
# [0.7195121893068639,
#  0.8414634204492336,
#  0.7682926742041983,
#  0.7682926858343729,
#  0.7073170760782753,
#  0.8170731736392509,
#  0.6707317160397042,
#  0.7073170760782753,
#  0.7804877961554179,
#  0.7073170644481007,
#  0.7926829239217247,
#  0.7317073112580834,
#  0.7804878165082234,
#  0.7560975638831534,
#  0.8048780458729442,
#  0.7926829239217247,
#  0.792682921014181,
#  0.8170731736392509,
#  0.7439024506545648,
#  0.7195121922144075,
#  0.8170731707317073,
#  0.7560975609756098,
#  0.7560975609756098,
#  0.6707317044095296,
#  0.7317073257958017,
#  0.6951219512195121,
#  0.7682926742041983,
#  0.8658536556290417,
#  0.7560975638831534,
#  0.7439024215791283,
#  0.7682927003720912,
#  0.768292677111742,
#  0.7195121820380048,
#  0.792682921014181,
#  0.7317073257958017,
#  0.792682921014181,
#  0.8170731707317073,
#  0.7804878136006798,
#  0.7804878136006798,
#  0.695121968664774,
#  0.7317073287033453,
#  0.7317073257958017,
#  0.7682926858343729,
#  0.8048780604106623,
#  0.7926829355518993,
#  0.7439024506545648,
#  0.756097575513328,
#  0.7317073112580834,
#  0.6951219541270558,
#  0.6951219541270558]

# %%
max_val_accs.mean()
# Out:
# 0.7575609772089049

# %%
max_val_accs.std()
# Out:
# 0.0435377805456792
