# %%
from keras import layers
from keras import models
from keras import optimizers
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
from numpy import random
import os
from os.path import isfile, join
import pandas as pd
from math import ceil
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
master_image_size = 256, 256
master_color_channels = 1
random.seed(0)
base_image_dir = 'grayscale-256x256'

# %%
def get_new_model():
    """
    Creates a new CNN model. It also prints a summary of the
    model.
    
    It uses the external variables master_image_size and
    master_color_channels to setup the input layer.
    
    Returns
    -------
    keras.models.Sequential
        The model ready to be trained
    """
    model = models.Sequential()
    model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(master_image_size[0], master_image_size[1], master_color_channels)))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Flatten())
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer=optimizers.RMSprop(lr=0.5e-4), metrics=['acc'])
    
    model.summary()
    
    return model

# %%
def train_validation_test(base_path, shuffle_seed=0):
    """
    Reads images in a directory and splits them up according to class
    
    Assumes a binary classification, with EQUAL COUNTS in each
    class.
    
    This automatically assigns classes to the images. It assumes
    the name of each class is the first token of the filename as
    delimited by "_".
    
    The dataframes returned are to be used by Keras. They have the
    columns "filename" and "class" to point to the images and the
    classes, repectively.
    
    Parameters
    ----------
    base_path : str
        The relative path to the images.
        
    shuffle_seed : int
        The integer to seed the random number generator which shuffles
        the dataframe.
        
    Returns
    -------
    pd.DataFrame, pd.DataFrame, pd.DataFrame
        The train, validation and test sets, respectively.
    """
    print(f'>>> Shuffle seed {shuffle_seed}')
    
    train_fraction = 0.8
    random.seed(shuffle_seed)
    
    all_images_list = []
    
    for filename in os.listdir(base_path):
        if isfile(join(base_path, filename)):
            image_class = filename.split('.')[0]
            all_images_list.append({'class': image_class, 'filename': filename})
    
    all_images = pd.DataFrame(all_images_list)
    all_images = all_images.sample(frac=1).reset_index(drop=True)
    all_classes = all_images['class'].unique()
    
    first_class_name = all_classes[0]
    second_class_name = all_classes[1]
    
    first_class = all_images.copy().where(all_images['class'] == first_class_name).dropna()
    second_class = all_images.copy().where(all_images['class'] == second_class_name).dropna()

    train_row_count = int(len(first_class) * train_fraction)
    test_val_count = len(first_class) - train_row_count
    
    first_class_train = first_class.iloc[2 * test_val_count:]
    first_class_val = first_class.iloc[test_val_count:2 * test_val_count]
    first_class_test = first_class.iloc[0:test_val_count]
    
    second_class_train = second_class.iloc[2 * test_val_count:]
    second_class_val = second_class.iloc[test_val_count:2 * test_val_count]
    second_class_test = second_class.iloc[0:test_val_count]
    
    train = first_class_train.append(second_class_train).reset_index().drop('index', axis=1)
    val = first_class_val.append(second_class_val).reset_index().drop('index', axis=1)
    test = first_class_test.append(second_class_test).reset_index().drop('index', axis=1)
    
    print(first_class_name, second_class_name)
    
    return train, val, test

# %%
def train_validation_test_generators(src_dir, shuffle_seed=0):
    """
    Creates generators for train, validation and test datasets. These
    can then be used by Keras to train a model.
    
    Dataframe shuffling is prevented at this step because the dataframe
    is assumed to have been shuffled beforehand with an RNG with a known
    seed.
    
    The dataframe is created for you from the images in src_dir. See the
    train_validation_test function for more information.
    
    Parameters
    ----------
    src_dir : str
        The relative path to the train, validation and test images
        
    shuffle_seed : int
        The seed for the RNG used for dataframe shuffling.
        
    Returns
    -------
    """
    train, validation, test = train_validation_test(src_dir, shuffle_seed)

    train_datagen = image.ImageDataGenerator(rescale=1.0/255)
    test_datagen = image.ImageDataGenerator(rescale=1.0/255)
    validation_datagen = image.ImageDataGenerator(rescale=1.0/255)

    train_generator = train_datagen.flow_from_dataframe(dataframe=train,
                                                        directory=src_dir,
                                                        target_size=master_image_size,
                                                        batch_size=20,
                                                        shuffle=False,
                                                        color_mode='grayscale',
                                                        class_mode='binary')

    validation_generator = train_datagen.flow_from_dataframe(dataframe=validation,
                                                      directory=src_dir,
                                                      target_size=master_image_size,
                                                      batch_size=20,
                                                      shuffle=False,
                                                      color_mode='grayscale',
                                                      class_mode='binary')

    test_generator = train_datagen.flow_from_dataframe(dataframe=test,
                                                       directory=src_dir,
                                                       target_size=master_image_size,
                                                       batch_size=20,
                                                       shuffle=False,
                                                       color_mode='grayscale',
                                                       class_mode='binary')
    
    return train_generator, validation_generator, test_generator

# %%
def train_model_and_get_history(base_image_dir, shuffle_seed=0, epochs=10):
    """
    Trains a model and returns the RNG seed and history
    
    Parameters
    ----------
    base_image_dir : str
        The relative path to the images.
        
    shuffle_seed : int
        The seed for the RNG that shuffles the train, validation
        and test datasets.
        
    Returns
    -------
    keras.model.Sequential, dict
        The model that created the history
    """
    train_generator, validation_generator, test_generator = train_validation_test_generators(base_image_dir, shuffle_seed)
    model = get_new_model()
    train_history = model.fit_generator(train_generator,
                                        steps_per_epoch=100,
                                        epochs=epochs,
                                        validation_data=validation_generator,
                                        validation_steps=50,
                                        verbose=1)
    return model, train_history

# %%
def train_and_run_different_shuffles(shuffles, src_image_dir, epochs_per_shuffle=10):
    histories = []
    for seed in range(shuffles):
        model, history = train_model_and_get_history(src_image_dir, seed, epochs=epochs_per_shuffle)
        histories.append({
            'seed': seed,
            'epochs': epochs_per_shuffle,
            'history': history,
            'model': model
        })
    return histories

# %%
histories = train_and_run_different_shuffles(10, src_image_dir=base_image_dir, epochs_per_shuffle=10)
# Out:
# >>> Shuffle seed 0
# benzene_ring non_benzene_ring
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# WARNING:tensorflow:From /home/alicia/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               590080
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /home/alicia/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 100/100 [==============================] - 15s 148ms/step - loss: 0.6973 - acc: 0.4418 - val_loss: 0.6926 - val_acc: 0.6098
# Epoch 2/10
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6942 - acc: 0.5072 - val_loss: 0.6916 - val_acc: 0.5976
# Epoch 3/10
# 100/100 [==============================] - 12s 121ms/step - loss: 0.6887 - acc: 0.5657 - val_loss: 0.6922 - val_acc: 0.5000
# Epoch 4/10
# 100/100 [==============================] - 12s 122ms/step - loss: 0.6828 - acc: 0.5923 - val_loss: 0.6830 - val_acc: 0.5000
# Epoch 5/10
# 100/100 [==============================] - 12s 123ms/step - loss: 0.6597 - acc: 0.6463 - val_loss: 0.6579 - val_acc: 0.6098
# Epoch 6/10
# 100/100 [==============================] - 12s 123ms/step - loss: 0.6062 - acc: 0.7111 - val_loss: 0.6215 - val_acc: 0.6463
# Epoch 7/10
# 100/100 [==============================] - 13s 127ms/step - loss: 0.5397 - acc: 0.7463 - val_loss: 0.6311 - val_acc: 0.6463
# Epoch 8/10
# 100/100 [==============================] - 12s 121ms/step - loss: 0.5022 - acc: 0.7644 - val_loss: 0.6267 - val_acc: 0.6829
# Epoch 9/10
# 100/100 [==============================] - 12s 120ms/step - loss: 0.4669 - acc: 0.7994 - val_loss: 0.6155 - val_acc: 0.6951
# Epoch 10/10
# 100/100 [==============================] - 12s 121ms/step - loss: 0.4222 - acc: 0.8189 - val_loss: 0.7065 - val_acc: 0.6463
# >>> Shuffle seed 1
# non_benzene_ring benzene_ring
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               590080
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 100/100 [==============================] - 12s 121ms/step - loss: 0.7003 - acc: 0.4507 - val_loss: 0.6923 - val_acc: 0.5244
# Epoch 2/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.6955 - acc: 0.4787 - val_loss: 0.6908 - val_acc: 0.6951
# Epoch 3/10
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6916 - acc: 0.5367 - val_loss: 0.6892 - val_acc: 0.5000
# Epoch 4/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.6898 - acc: 0.5323 - val_loss: 0.6809 - val_acc: 0.5000
# Epoch 5/10
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6784 - acc: 0.5763 - val_loss: 0.6607 - val_acc: 0.7439
# Epoch 6/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.6457 - acc: 0.6563 - val_loss: 0.6219 - val_acc: 0.7195
# Epoch 7/10
# 100/100 [==============================] - 12s 121ms/step - loss: 0.5895 - acc: 0.6958 - val_loss: 0.5821 - val_acc: 0.7439
# Epoch 8/10
# 100/100 [==============================] - 12s 124ms/step - loss: 0.5371 - acc: 0.7413 - val_loss: 0.5415 - val_acc: 0.7439
# Epoch 9/10
# 100/100 [==============================] - 12s 123ms/step - loss: 0.4984 - acc: 0.7699 - val_loss: 0.5211 - val_acc: 0.7561
# Epoch 10/10
# 100/100 [==============================] - 12s 124ms/step - loss: 0.4652 - acc: 0.7934 - val_loss: 0.5760 - val_acc: 0.7439
# >>> Shuffle seed 2
# benzene_ring non_benzene_ring
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               590080
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 100/100 [==============================] - 12s 123ms/step - loss: 0.6978 - acc: 0.4644 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 2/10
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6942 - acc: 0.4772 - val_loss: 0.6920 - val_acc: 0.5976
# Epoch 3/10
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6913 - acc: 0.5632 - val_loss: 0.6887 - val_acc: 0.5000
# Epoch 4/10
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6878 - acc: 0.5748 - val_loss: 0.6817 - val_acc: 0.5488
# Epoch 5/10
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6709 - acc: 0.6243 - val_loss: 0.6733 - val_acc: 0.5610
# Epoch 6/10
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6342 - acc: 0.6733 - val_loss: 0.6326 - val_acc: 0.7073
# Epoch 7/10
# 100/100 [==============================] - 12s 121ms/step - loss: 0.5816 - acc: 0.7249 - val_loss: 0.6316 - val_acc: 0.6829
# Epoch 8/10
# 100/100 [==============================] - 12s 125ms/step - loss: 0.5381 - acc: 0.7504 - val_loss: 0.6482 - val_acc: 0.6220
# Epoch 9/10
# 100/100 [==============================] - 12s 122ms/step - loss: 0.5107 - acc: 0.7569 - val_loss: 0.6196 - val_acc: 0.6463
# Epoch 10/10
# 100/100 [==============================] - 12s 123ms/step - loss: 0.4718 - acc: 0.7714 - val_loss: 0.6843 - val_acc: 0.6585
# >>> Shuffle seed 3
# non_benzene_ring benzene_ring
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               590080
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 100/100 [==============================] - 13s 126ms/step - loss: 0.7028 - acc: 0.4712 - val_loss: 0.6924 - val_acc: 0.5000
# Epoch 2/10
# 100/100 [==============================] - 12s 119ms/step - loss: 0.6950 - acc: 0.4732 - val_loss: 0.6908 - val_acc: 0.6098
# Epoch 3/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.6891 - acc: 0.5427 - val_loss: 0.6847 - val_acc: 0.5000
# Epoch 4/10
# 100/100 [==============================] - 12s 121ms/step - loss: 0.6793 - acc: 0.5768 - val_loss: 0.6641 - val_acc: 0.6098
# Epoch 5/10
# 100/100 [==============================] - 12s 122ms/step - loss: 0.6464 - acc: 0.6498 - val_loss: 0.6448 - val_acc: 0.6341
# Epoch 6/10
# 100/100 [==============================] - 12s 122ms/step - loss: 0.5915 - acc: 0.6908 - val_loss: 0.5806 - val_acc: 0.6707
# Epoch 7/10
# 100/100 [==============================] - 12s 119ms/step - loss: 0.5359 - acc: 0.7274 - val_loss: 0.5726 - val_acc: 0.7195
# Epoch 8/10
# 100/100 [==============================] - 12s 120ms/step - loss: 0.4910 - acc: 0.7644 - val_loss: 0.6128 - val_acc: 0.7195
# Epoch 9/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.4459 - acc: 0.8114 - val_loss: 0.5796 - val_acc: 0.7561
# Epoch 10/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.4018 - acc: 0.8454 - val_loss: 0.6716 - val_acc: 0.6463
# >>> Shuffle seed 4
# non_benzene_ring benzene_ring
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               590080
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 100/100 [==============================] - 12s 121ms/step - loss: 0.6992 - acc: 0.4561 - val_loss: 0.6918 - val_acc: 0.5366
# Epoch 2/10
# 100/100 [==============================] - 12s 121ms/step - loss: 0.6925 - acc: 0.5047 - val_loss: 0.6888 - val_acc: 0.5488
# Epoch 3/10
# 100/100 [==============================] - 12s 118ms/step - loss: 0.6831 - acc: 0.5612 - val_loss: 0.6828 - val_acc: 0.5000
# Epoch 4/10
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6704 - acc: 0.5783 - val_loss: 0.6630 - val_acc: 0.5610
# Epoch 5/10
# 100/100 [==============================] - 12s 122ms/step - loss: 0.6263 - acc: 0.6858 - val_loss: 0.6249 - val_acc: 0.6707
# Epoch 6/10
# 100/100 [==============================] - 12s 123ms/step - loss: 0.5520 - acc: 0.7569 - val_loss: 0.5884 - val_acc: 0.6951
# Epoch 7/10
# 100/100 [==============================] - 12s 125ms/step - loss: 0.5041 - acc: 0.7739 - val_loss: 0.6024 - val_acc: 0.6585
# Epoch 8/10
# 100/100 [==============================] - 12s 123ms/step - loss: 0.4693 - acc: 0.7924 - val_loss: 0.5752 - val_acc: 0.7805
# Epoch 9/10
# 100/100 [==============================] - 12s 122ms/step - loss: 0.4400 - acc: 0.8149 - val_loss: 0.5691 - val_acc: 0.7561
# Epoch 10/10
# 100/100 [==============================] - 13s 125ms/step - loss: 0.4180 - acc: 0.8339 - val_loss: 0.6327 - val_acc: 0.6463
# >>> Shuffle seed 5
# non_benzene_ring benzene_ring
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_26 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 100/100 [==============================] - 13s 128ms/step - loss: 0.7008 - acc: 0.4612 - val_loss: 0.6924 - val_acc: 0.6341
# Epoch 2/10
# 100/100 [==============================] - 12s 119ms/step - loss: 0.6937 - acc: 0.5102 - val_loss: 0.6906 - val_acc: 0.5732
# Epoch 3/10
# 100/100 [==============================] - 12s 119ms/step - loss: 0.6853 - acc: 0.5722 - val_loss: 0.6883 - val_acc: 0.5000
# Epoch 4/10
# 100/100 [==============================] - 13s 129ms/step - loss: 0.6730 - acc: 0.5953 - val_loss: 0.6718 - val_acc: 0.5366
# Epoch 5/10
# 100/100 [==============================] - 12s 123ms/step - loss: 0.6319 - acc: 0.6648 - val_loss: 0.6500 - val_acc: 0.6707
# Epoch 6/10
# 100/100 [==============================] - 12s 120ms/step - loss: 0.5654 - acc: 0.7494 - val_loss: 0.6188 - val_acc: 0.6829
# Epoch 7/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.5153 - acc: 0.7769 - val_loss: 0.6295 - val_acc: 0.6463
# Epoch 8/10
# 100/100 [==============================] - 12s 118ms/step - loss: 0.4784 - acc: 0.7864 - val_loss: 0.6566 - val_acc: 0.7073
# Epoch 9/10
# 100/100 [==============================] - 12s 122ms/step - loss: 0.4507 - acc: 0.8139 - val_loss: 0.6266 - val_acc: 0.7439
# Epoch 10/10
# 100/100 [==============================] - 12s 119ms/step - loss: 0.4135 - acc: 0.8419 - val_loss: 0.6858 - val_acc: 0.6220
# >>> Shuffle seed 6
# non_benzene_ring benzene_ring
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_31 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 100/100 [==============================] - 12s 119ms/step - loss: 0.7005 - acc: 0.4672 - val_loss: 0.6926 - val_acc: 0.5244
# Epoch 2/10
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6948 - acc: 0.4742 - val_loss: 0.6915 - val_acc: 0.5732
# Epoch 3/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.6904 - acc: 0.5487 - val_loss: 0.6889 - val_acc: 0.5000
# Epoch 4/10
# 100/100 [==============================] - 12s 124ms/step - loss: 0.6867 - acc: 0.5563 - val_loss: 0.6818 - val_acc: 0.5000
# Epoch 5/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.6733 - acc: 0.5983 - val_loss: 0.6679 - val_acc: 0.6585
# Epoch 6/10
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6383 - acc: 0.6628 - val_loss: 0.6410 - val_acc: 0.6341
# Epoch 7/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.5858 - acc: 0.7003 - val_loss: 0.6370 - val_acc: 0.6341
# Epoch 8/10
# 100/100 [==============================] - 12s 121ms/step - loss: 0.5344 - acc: 0.7323 - val_loss: 0.6246 - val_acc: 0.6463
# Epoch 9/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.4976 - acc: 0.7544 - val_loss: 0.6049 - val_acc: 0.7195
# Epoch 10/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.4662 - acc: 0.7684 - val_loss: 0.6602 - val_acc: 0.6829
# >>> Shuffle seed 7
# non_benzene_ring benzene_ring
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_36 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 100/100 [==============================] - 12s 125ms/step - loss: 0.7041 - acc: 0.4514 - val_loss: 0.6925 - val_acc: 0.5366
# Epoch 2/10
# 100/100 [==============================] - 12s 120ms/step - loss: 0.6961 - acc: 0.4877 - val_loss: 0.6917 - val_acc: 0.6341
# Epoch 3/10
# 100/100 [==============================] - 12s 118ms/step - loss: 0.6917 - acc: 0.5447 - val_loss: 0.6907 - val_acc: 0.5000
# Epoch 4/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.6887 - acc: 0.5573 - val_loss: 0.6825 - val_acc: 0.5000
# Epoch 5/10
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6733 - acc: 0.6013 - val_loss: 0.6682 - val_acc: 0.6220
# Epoch 6/10
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6362 - acc: 0.6638 - val_loss: 0.6220 - val_acc: 0.7073
# Epoch 7/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.5878 - acc: 0.7089 - val_loss: 0.5874 - val_acc: 0.7073
# Epoch 8/10
# 100/100 [==============================] - 12s 116ms/step - loss: 0.5479 - acc: 0.7388 - val_loss: 0.5794 - val_acc: 0.7195
# Epoch 9/10
# 100/100 [==============================] - 12s 116ms/step - loss: 0.5158 - acc: 0.7504 - val_loss: 0.5456 - val_acc: 0.7439
# Epoch 10/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.4841 - acc: 0.7679 - val_loss: 0.5795 - val_acc: 0.7195
# >>> Shuffle seed 8
# benzene_ring non_benzene_ring
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_41 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_42 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_43 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_44 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_45 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 100/100 [==============================] - 12s 122ms/step - loss: 0.6974 - acc: 0.4522 - val_loss: 0.6927 - val_acc: 0.5000
# Epoch 2/10
# 100/100 [==============================] - 12s 118ms/step - loss: 0.6946 - acc: 0.4602 - val_loss: 0.6921 - val_acc: 0.5366
# Epoch 3/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.6921 - acc: 0.5302 - val_loss: 0.6910 - val_acc: 0.5000
# Epoch 4/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.6893 - acc: 0.5753 - val_loss: 0.6857 - val_acc: 0.5366
# Epoch 5/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.6779 - acc: 0.6188 - val_loss: 0.6661 - val_acc: 0.6707
# Epoch 6/10
# 100/100 [==============================] - 12s 122ms/step - loss: 0.6388 - acc: 0.6988 - val_loss: 0.6275 - val_acc: 0.6585
# Epoch 7/10
# 100/100 [==============================] - 12s 119ms/step - loss: 0.5637 - acc: 0.7544 - val_loss: 0.6138 - val_acc: 0.6585
# Epoch 8/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.4954 - acc: 0.7844 - val_loss: 0.6204 - val_acc: 0.7073
# Epoch 9/10
# 100/100 [==============================] - 12s 116ms/step - loss: 0.4513 - acc: 0.8079 - val_loss: 0.6204 - val_acc: 0.6829
# Epoch 10/10
# 100/100 [==============================] - 12s 120ms/step - loss: 0.4156 - acc: 0.8134 - val_loss: 0.6719 - val_acc: 0.7439
# >>> Shuffle seed 9
# benzene_ring non_benzene_ring
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_46 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_46 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_47 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_50 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 100/100 [==============================] - 13s 131ms/step - loss: 0.7006 - acc: 0.4495 - val_loss: 0.6920 - val_acc: 0.6463
# Epoch 2/10
# 100/100 [==============================] - 12s 119ms/step - loss: 0.6950 - acc: 0.4897 - val_loss: 0.6909 - val_acc: 0.5732
# Epoch 3/10
# 100/100 [==============================] - 13s 127ms/step - loss: 0.6913 - acc: 0.5542 - val_loss: 0.6893 - val_acc: 0.5000
# Epoch 4/10
# 100/100 [==============================] - 12s 124ms/step - loss: 0.6853 - acc: 0.6193 - val_loss: 0.6773 - val_acc: 0.6463
# Epoch 5/10
# 100/100 [==============================] - 12s 123ms/step - loss: 0.6612 - acc: 0.6983 - val_loss: 0.6443 - val_acc: 0.6829
# Epoch 6/10
# 100/100 [==============================] - 12s 124ms/step - loss: 0.6038 - acc: 0.7521 - val_loss: 0.6064 - val_acc: 0.7317
# Epoch 7/10
# 100/100 [==============================] - 13s 127ms/step - loss: 0.5262 - acc: 0.7903 - val_loss: 0.6267 - val_acc: 0.7195
# Epoch 8/10
# 100/100 [==============================] - 12s 119ms/step - loss: 0.4880 - acc: 0.7996 - val_loss: 0.5990 - val_acc: 0.6829
# Epoch 9/10
# 100/100 [==============================] - 12s 118ms/step - loss: 0.4508 - acc: 0.8107 - val_loss: 0.6083 - val_acc: 0.7073
# Epoch 10/10
# 100/100 [==============================] - 12s 121ms/step - loss: 0.4115 - acc: 0.8333 - val_loss: 0.7477 - val_acc: 0.7683
