# %%
from keras import layers
from keras import models
from keras import optimizers
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
from numpy import random
import os
from os.path import isfile, join
import pandas as pd
from math import ceil
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
class ConvnetSneakers:
    def __init__(self, base_image_path, master_image_size, master_color_channels):
        self.master_image_size = master_image_size
        self.base_image_path = base_image_path
        self.master_color_channels = master_color_channels
    
    def get_new_model(self):
        """
        Creates a new CNN model. It also prints a summary of the
        model.

        It uses the external variables master_image_size and
        master_color_channels to setup the input layer.

        Returns
        -------
        keras.models.Sequential
            The model ready to be trained
        """
        model = models.Sequential()
        model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(self.master_image_size[0],
                                                                            self.master_image_size[1],
                                                                            self.master_color_channels)))
        model.add(layers.MaxPooling2D((2, 2)))
        model.add(layers.Conv2D(64, (3, 3), activation='relu'))
        model.add(layers.MaxPooling2D((2, 2)))
        model.add(layers.Conv2D(64, (3, 3), activation='relu'))
        model.add(layers.MaxPooling2D((2, 2)))
        model.add(layers.Conv2D(64, (3, 3), activation='relu'))
        model.add(layers.MaxPooling2D((2, 2)))
        model.add(layers.Conv2D(64, (3, 3), activation='relu'))
        model.add(layers.MaxPooling2D((2, 2)))
        model.add(layers.Flatten())
        model.add(layers.Dense(256, activation='relu'))
        model.add(layers.Dense(1, activation='sigmoid'))
        model.compile(loss='binary_crossentropy', optimizer=optimizers.RMSprop(lr=0.5e-4), metrics=['acc'])

        model.summary()

        return model
    
    def train_validation_test(self, shuffle_seed=0):
        """
        Reads images in a directory and splits them up according to class

        Assumes a binary classification, with EQUAL COUNTS in each
        class.

        This automatically assigns classes to the images. It assumes
        the name of each class is the first token of the filename as
        delimited by "_".

        The dataframes returned are to be used by Keras. They have the
        columns "filename" and "class" to point to the images and the
        classes, repectively.

        Parameters
        ----------
        shuffle_seed : int
            The integer to seed the random number generator which shuffles
            the dataframe.

        Returns
        -------
        pd.DataFrame, pd.DataFrame, pd.DataFrame
            The train, validation and test sets, respectively.
        """
        print(f'>>> Shuffle seed {shuffle_seed}')

        train_fraction = 0.8
        random.seed(shuffle_seed)

        all_images_list = []

        for filename in os.listdir(self.base_image_path):
            if isfile(join(self.base_image_path, filename)):
                image_class = filename.split('.')[0]
                all_images_list.append({'class': image_class, 'filename': filename})

        all_images = pd.DataFrame(all_images_list)
        all_images = all_images.sample(frac=1).reset_index(drop=True)
        all_classes = all_images['class'].unique()

        first_class_name = all_classes[0]
        second_class_name = all_classes[1]

        first_class = all_images.copy().where(all_images['class'] == first_class_name).dropna()
        second_class = all_images.copy().where(all_images['class'] == second_class_name).dropna()

        train_row_count = int(len(first_class) * train_fraction)
        test_val_count = len(first_class) - train_row_count

        first_class_train = first_class.iloc[2 * test_val_count:]
        first_class_val = first_class.iloc[test_val_count:2 * test_val_count]
        first_class_test = first_class.iloc[0:test_val_count]

        second_class_train = second_class.iloc[2 * test_val_count:]
        second_class_val = second_class.iloc[test_val_count:2 * test_val_count]
        second_class_test = second_class.iloc[0:test_val_count]

        train = first_class_train.append(second_class_train).reset_index().drop('index', axis=1)
        val = first_class_val.append(second_class_val).reset_index().drop('index', axis=1)
        test = first_class_test.append(second_class_test).reset_index().drop('index', axis=1)

        print(first_class_name, second_class_name)

        return train, val, test
    
    def train_validation_test_generators(self, shuffle_seed=0):
        """
        Creates generators for train, validation and test datasets. These
        can then be used by Keras to train a model.

        Dataframe shuffling is prevented at this step because the dataframe
        is assumed to have been shuffled beforehand with an RNG with a known
        seed.

        The dataframe is created for you from the images in src_dir. See the
        train_validation_test function for more information.

        Parameters
        ----------
        shuffle_seed : int
            The seed for the RNG used for dataframe shuffling.

        Returns
        -------
        """
        train, validation, test = self.train_validation_test(shuffle_seed)

        train_datagen = image.ImageDataGenerator(rescale=1.0/255)
        test_datagen = image.ImageDataGenerator(rescale=1.0/255)
        validation_datagen = image.ImageDataGenerator(rescale=1.0/255)

        train_generator = train_datagen.flow_from_dataframe(dataframe=train,
                                                            directory=self.base_image_path,
                                                            target_size=self.master_image_size,
                                                            batch_size=20,
                                                            shuffle=False,
                                                            color_mode='grayscale',
                                                            class_mode='binary')

        validation_generator = train_datagen.flow_from_dataframe(dataframe=validation,
                                                          directory=self.base_image_path,
                                                          target_size=self.master_image_size,
                                                          batch_size=20,
                                                          shuffle=False,
                                                          color_mode='grayscale',
                                                          class_mode='binary')

        test_generator = train_datagen.flow_from_dataframe(dataframe=test,
                                                           directory=self.base_image_path,
                                                           target_size=self.master_image_size,
                                                           batch_size=20,
                                                           shuffle=False,
                                                           color_mode='grayscale',
                                                           class_mode='binary')

        return train_generator, validation_generator, test_generator
    
    def train_model_and_get_history(self, shuffle_seed=0, epochs=10):
        """
        Trains a model and returns the RNG seed and history

        Parameters
        ----------
        shuffle_seed : int
            The seed for the RNG that shuffles the train, validation
            and test datasets.

        Returns
        -------
        keras.model.Sequential, dict
            The model that created the history
        """
        train_generator, validation_generator, test_generator = self.train_validation_test_generators(shuffle_seed)
        model = self.get_new_model()
        train_history = model.fit_generator(train_generator,
                                            steps_per_epoch=100,
                                            epochs=epochs,
                                            validation_data=validation_generator,
                                            validation_steps=50,
                                            verbose=1)
        return model, train_history
    
    def train_and_run_different_shuffles(self, shuffles=10, epochs_per_shuffle=10):
        """
        This runs a sequence of trainings, each with a different shuffle
        controlled by a different random number generator.
        
        Parameters
        ----------
        shuffles : int
            The number of shuffles and training runs to go.
            
        epochs_per_shuffle : int
            The number of epochs in each shuffle of the data.
        """
        histories = []
        for shuffle_seed in range(shuffles):
            model, history = self.train_model_and_get_history(shuffle_seed, epochs=epochs_per_shuffle)
            train, validation, test = self.train_validation_test(shuffle_seed)
            histories.append({
                'shuffle_seed': shuffle_seed,
                'epochs': epochs_per_shuffle,
                'val_accs': history.history['val_acc'],
                'model': model,
                'train': train,
                'validation': validation,
                'test': test
            })
        return histories

# %%
trainer = ConvnetSneakers(master_image_size=(256, 256), base_image_path='grayscale-256x256', master_color_channels=1)
histories = trainer.train_and_run_different_shuffles(2, 2)
# Out:
# >>> Shuffle seed 0
# benzene_ring non_benzene_ring
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_46 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_46 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_47 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_50 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 100/100 [==============================] - 12s 123ms/step - loss: 0.6974 - acc: 0.4443 - val_loss: 0.6928 - val_acc: 0.5732
# Epoch 2/2
# 100/100 [==============================] - 12s 118ms/step - loss: 0.6946 - acc: 0.5087 - val_loss: 0.6917 - val_acc: 0.5732
# >>> Shuffle seed 0
# non_benzene_ring benzene_ring
# >>> Shuffle seed 1
# benzene_ring non_benzene_ring
# Found 246 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# Found 82 validated image filenames belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_51 (Conv2D)           (None, 254, 254, 64)      640
# _________________________________________________________________
# max_pooling2d_51 (MaxPooling (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 125, 125, 64)      36928
# _________________________________________________________________
# max_pooling2d_52 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_53 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_54 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_55 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 738,689
# Trainable params: 738,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 100/100 [==============================] - 12s 122ms/step - loss: 0.6984 - acc: 0.4656 - val_loss: 0.6920 - val_acc: 0.5000
# Epoch 2/2
# 100/100 [==============================] - 11s 115ms/step - loss: 0.6945 - acc: 0.4707 - val_loss: 0.6911 - val_acc: 0.7561
# >>> Shuffle seed 1
# non_benzene_ring benzene_ring

# %%
histories
# Out:
# [{'shuffle_seed': 0,
#   'epochs': 2,
#   'val_accs': [0.5731707335245319, 0.5731707346148607],
#   'model': <keras.engine.sequential.Sequential at 0x7f819aba2cf8>,
#   'train':                 class                   filename
#   0    non_benzene_ring  non_benzene_ring.0187.jpg
#   1    non_benzene_ring  non_benzene_ring.0192.jpg
#   2    non_benzene_ring  non_benzene_ring.9978.jpg
#   3    non_benzene_ring  non_benzene_ring.0180.jpg
#   4    non_benzene_ring  non_benzene_ring.0119.jpg
#   5    non_benzene_ring  non_benzene_ring.0171.jpg
#   6    non_benzene_ring  non_benzene_ring.0181.jpg
#   7    non_benzene_ring  non_benzene_ring.0172.jpg
#   8    non_benzene_ring  non_benzene_ring.0160.jpg
#   9    non_benzene_ring  non_benzene_ring.0134.jpg
#   10   non_benzene_ring  non_benzene_ring.9967.jpg
#   11   non_benzene_ring  non_benzene_ring.9972.jpg
#   12   non_benzene_ring  non_benzene_ring.0118.jpg
#   13   non_benzene_ring  non_benzene_ring.0194.jpg
#   14   non_benzene_ring  non_benzene_ring.0201.jpg
#   15   non_benzene_ring  non_benzene_ring.9952.jpg
#   16   non_benzene_ring  non_benzene_ring.0123.jpg
#   17   non_benzene_ring  non_benzene_ring.9977.jpg
#   18   non_benzene_ring  non_benzene_ring.9916.jpg
#   19   non_benzene_ring  non_benzene_ring.0107.jpg
#   20   non_benzene_ring  non_benzene_ring.9907.jpg
#   21   non_benzene_ring  non_benzene_ring.9961.jpg
#   22   non_benzene_ring  non_benzene_ring.9914.jpg
#   23   non_benzene_ring  non_benzene_ring.9906.jpg
#   24   non_benzene_ring  non_benzene_ring.9936.jpg
#   25   non_benzene_ring  non_benzene_ring.9948.jpg
#   26   non_benzene_ring  non_benzene_ring.9899.jpg
#   27   non_benzene_ring  non_benzene_ring.9947.jpg
#   28   non_benzene_ring  non_benzene_ring.0208.jpg
#   29   non_benzene_ring  non_benzene_ring.0127.jpg
#   ..                ...                        ...
#   216      benzene_ring      benzene_ring.9799.jpg
#   217      benzene_ring      benzene_ring.0028.jpg
#   218      benzene_ring      benzene_ring.9790.jpg
#   219      benzene_ring      benzene_ring.9823.jpg
#   220      benzene_ring      benzene_ring.9849.jpg
#   221      benzene_ring      benzene_ring.0046.jpg
#   222      benzene_ring      benzene_ring.0071.jpg
#   223      benzene_ring      benzene_ring.9866.jpg
#   224      benzene_ring      benzene_ring.9862.jpg
#   225      benzene_ring      benzene_ring.9821.jpg
#   226      benzene_ring      benzene_ring.0090.jpg
#   227      benzene_ring      benzene_ring.9820.jpg
#   228      benzene_ring      benzene_ring.0041.jpg
#   229      benzene_ring      benzene_ring.0086.jpg
#   230      benzene_ring      benzene_ring.9788.jpg
#   231      benzene_ring      benzene_ring.0095.jpg
#   232      benzene_ring      benzene_ring.0069.jpg
#   233      benzene_ring      benzene_ring.9888.jpg
#   234      benzene_ring      benzene_ring.9880.jpg
#   235      benzene_ring      benzene_ring.0003.jpg
#   236      benzene_ring      benzene_ring.9868.jpg
#   237      benzene_ring      benzene_ring.0093.jpg
#   238      benzene_ring      benzene_ring.9884.jpg
#   239      benzene_ring      benzene_ring.9784.jpg
#   240      benzene_ring      benzene_ring.9797.jpg
#   241      benzene_ring      benzene_ring.0044.jpg
#   242      benzene_ring      benzene_ring.9890.jpg
#   243      benzene_ring      benzene_ring.0085.jpg
#   244      benzene_ring      benzene_ring.9847.jpg
#   245      benzene_ring      benzene_ring.9833.jpg
#
#   [246 rows x 2 columns],
#   'validation':                class                   filename
#   0   non_benzene_ring  non_benzene_ring.9909.jpg
#   1   non_benzene_ring  non_benzene_ring.0150.jpg
#   2   non_benzene_ring  non_benzene_ring.9951.jpg
#   3   non_benzene_ring  non_benzene_ring.0202.jpg
#   4   non_benzene_ring  non_benzene_ring.9911.jpg
#   5   non_benzene_ring  non_benzene_ring.0142.jpg
#   6   non_benzene_ring  non_benzene_ring.0108.jpg
#   7   non_benzene_ring  non_benzene_ring.0170.jpg
#   8   non_benzene_ring  non_benzene_ring.0145.jpg
#   9   non_benzene_ring  non_benzene_ring.0169.jpg
#   10  non_benzene_ring  non_benzene_ring.0162.jpg
#   11  non_benzene_ring  non_benzene_ring.9946.jpg
#   12  non_benzene_ring  non_benzene_ring.9937.jpg
#   13  non_benzene_ring  non_benzene_ring.0133.jpg
#   14  non_benzene_ring  non_benzene_ring.0163.jpg
#   15  non_benzene_ring  non_benzene_ring.9956.jpg
#   16  non_benzene_ring  non_benzene_ring.0191.jpg
#   17  non_benzene_ring  non_benzene_ring.0164.jpg
#   18  non_benzene_ring  non_benzene_ring.0112.jpg
#   19  non_benzene_ring  non_benzene_ring.9989.jpg
#   20  non_benzene_ring  non_benzene_ring.9955.jpg
#   21  non_benzene_ring  non_benzene_ring.9990.jpg
#   22  non_benzene_ring  non_benzene_ring.0203.jpg
#   23  non_benzene_ring  non_benzene_ring.9949.jpg
#   24  non_benzene_ring  non_benzene_ring.9985.jpg
#   25  non_benzene_ring  non_benzene_ring.9910.jpg
#   26  non_benzene_ring  non_benzene_ring.0197.jpg
#   27  non_benzene_ring  non_benzene_ring.0165.jpg
#   28  non_benzene_ring  non_benzene_ring.9903.jpg
#   29  non_benzene_ring  non_benzene_ring.9927.jpg
#   ..               ...                        ...
#   52      benzene_ring      benzene_ring.0084.jpg
#   53      benzene_ring      benzene_ring.9845.jpg
#   54      benzene_ring      benzene_ring.0087.jpg
#   55      benzene_ring      benzene_ring.0048.jpg
#   56      benzene_ring      benzene_ring.0039.jpg
#   57      benzene_ring      benzene_ring.0101.jpg
#   58      benzene_ring      benzene_ring.0097.jpg
#   59      benzene_ring      benzene_ring.9826.jpg
#   60      benzene_ring      benzene_ring.0012.jpg
#   61      benzene_ring      benzene_ring.9794.jpg
#   62      benzene_ring      benzene_ring.9831.jpg
#   63      benzene_ring      benzene_ring.0018.jpg
#   64      benzene_ring      benzene_ring.9881.jpg
#   65      benzene_ring      benzene_ring.9832.jpg
#   66      benzene_ring      benzene_ring.9873.jpg
#   67      benzene_ring      benzene_ring.0099.jpg
#   68      benzene_ring      benzene_ring.0062.jpg
#   69      benzene_ring      benzene_ring.0025.jpg
#   70      benzene_ring      benzene_ring.9869.jpg
#   71      benzene_ring      benzene_ring.9872.jpg
#   72      benzene_ring      benzene_ring.9795.jpg
#   73      benzene_ring      benzene_ring.9811.jpg
#   74      benzene_ring      benzene_ring.9813.jpg
#   75      benzene_ring      benzene_ring.0061.jpg
#   76      benzene_ring      benzene_ring.9835.jpg
#   77      benzene_ring      benzene_ring.9840.jpg
#   78      benzene_ring      benzene_ring.0103.jpg
#   79      benzene_ring      benzene_ring.9827.jpg
#   80      benzene_ring      benzene_ring.9818.jpg
#   81      benzene_ring      benzene_ring.0053.jpg
#
#   [82 rows x 2 columns],
#   'test':                class                   filename
#   0   non_benzene_ring  non_benzene_ring.0157.jpg
#   1   non_benzene_ring  non_benzene_ring.0178.jpg
#   2   non_benzene_ring  non_benzene_ring.9904.jpg
#   3   non_benzene_ring  non_benzene_ring.0179.jpg
#   4   non_benzene_ring  non_benzene_ring.0110.jpg
#   5   non_benzene_ring  non_benzene_ring.0124.jpg
#   6   non_benzene_ring  non_benzene_ring.0151.jpg
#   7   non_benzene_ring  non_benzene_ring.9953.jpg
#   8   non_benzene_ring  non_benzene_ring.0173.jpg
#   9   non_benzene_ring  non_benzene_ring.0199.jpg
#   10  non_benzene_ring  non_benzene_ring.9917.jpg
#   11  non_benzene_ring  non_benzene_ring.0126.jpg
#   12  non_benzene_ring  non_benzene_ring.9938.jpg
#   13  non_benzene_ring  non_benzene_ring.9902.jpg
#   14  non_benzene_ring  non_benzene_ring.9924.jpg
#   15  non_benzene_ring  non_benzene_ring.0129.jpg
#   16  non_benzene_ring  non_benzene_ring.9931.jpg
#   17  non_benzene_ring  non_benzene_ring.0161.jpg
#   18  non_benzene_ring  non_benzene_ring.9976.jpg
#   19  non_benzene_ring  non_benzene_ring.9974.jpg
#   20  non_benzene_ring  non_benzene_ring.0148.jpg
#   21  non_benzene_ring  non_benzene_ring.0115.jpg
#   22  non_benzene_ring  non_benzene_ring.0146.jpg
#   23  non_benzene_ring  non_benzene_ring.9929.jpg
#   24  non_benzene_ring  non_benzene_ring.0137.jpg
#   25  non_benzene_ring  non_benzene_ring.9963.jpg
#   26  non_benzene_ring  non_benzene_ring.0188.jpg
#   27  non_benzene_ring  non_benzene_ring.0155.jpg
#   28  non_benzene_ring  non_benzene_ring.0175.jpg
#   29  non_benzene_ring  non_benzene_ring.9930.jpg
#   ..               ...                        ...
#   52      benzene_ring      benzene_ring.0092.jpg
#   53      benzene_ring      benzene_ring.9828.jpg
#   54      benzene_ring      benzene_ring.9834.jpg
#   55      benzene_ring      benzene_ring.0037.jpg
#   56      benzene_ring      benzene_ring.0083.jpg
#   57      benzene_ring      benzene_ring.9850.jpg
#   58      benzene_ring      benzene_ring.0047.jpg
#   59      benzene_ring      benzene_ring.9870.jpg
#   60      benzene_ring      benzene_ring.9801.jpg
#   61      benzene_ring      benzene_ring.0024.jpg
#   62      benzene_ring      benzene_ring.0022.jpg
#   63      benzene_ring      benzene_ring.0038.jpg
#   64      benzene_ring      benzene_ring.0040.jpg
#   65      benzene_ring      benzene_ring.9783.jpg
#   66      benzene_ring      benzene_ring.0080.jpg
#   67      benzene_ring      benzene_ring.0091.jpg
#   68      benzene_ring      benzene_ring.0014.jpg
#   69      benzene_ring      benzene_ring.9861.jpg
#   70      benzene_ring      benzene_ring.9878.jpg
#   71      benzene_ring      benzene_ring.9785.jpg
#   72      benzene_ring      benzene_ring.0009.jpg
#   73      benzene_ring      benzene_ring.9808.jpg
#   74      benzene_ring      benzene_ring.9786.jpg
#   75      benzene_ring      benzene_ring.0098.jpg
#   76      benzene_ring      benzene_ring.9883.jpg
#   77      benzene_ring      benzene_ring.9792.jpg
#   78      benzene_ring      benzene_ring.0056.jpg
#   79      benzene_ring      benzene_ring.9793.jpg
#   80      benzene_ring      benzene_ring.0015.jpg
#   81      benzene_ring      benzene_ring.0031.jpg
#
#   [82 rows x 2 columns]},
#  {'shuffle_seed': 1,
#   'epochs': 2,
#   'val_accs': [0.5000000001817215, 0.7560975464378915],
#   'model': <keras.engine.sequential.Sequential at 0x7f81990aa9b0>,
#   'train':                 class                   filename
#   0    non_benzene_ring  non_benzene_ring.0180.jpg
#   1    non_benzene_ring  non_benzene_ring.0178.jpg
#   2    non_benzene_ring  non_benzene_ring.0200.jpg
#   3    non_benzene_ring  non_benzene_ring.0111.jpg
#   4    non_benzene_ring  non_benzene_ring.0146.jpg
#   5    non_benzene_ring  non_benzene_ring.9960.jpg
#   6    non_benzene_ring  non_benzene_ring.9950.jpg
#   7    non_benzene_ring  non_benzene_ring.9948.jpg
#   8    non_benzene_ring  non_benzene_ring.0147.jpg
#   9    non_benzene_ring  non_benzene_ring.0210.jpg
#   10   non_benzene_ring  non_benzene_ring.0016.jpg
#   11   non_benzene_ring  non_benzene_ring.0202.jpg
#   12   non_benzene_ring  non_benzene_ring.9954.jpg
#   13   non_benzene_ring  non_benzene_ring.9963.jpg
#   14   non_benzene_ring  non_benzene_ring.0117.jpg
#   15   non_benzene_ring  non_benzene_ring.0206.jpg
#   16   non_benzene_ring  non_benzene_ring.0181.jpg
#   17   non_benzene_ring  non_benzene_ring.9958.jpg
#   18   non_benzene_ring  non_benzene_ring.9901.jpg
#   19   non_benzene_ring  non_benzene_ring.9935.jpg
#   20   non_benzene_ring  non_benzene_ring.0160.jpg
#   21   non_benzene_ring  non_benzene_ring.0209.jpg
#   22   non_benzene_ring  non_benzene_ring.9968.jpg
#   23   non_benzene_ring  non_benzene_ring.0124.jpg
#   24   non_benzene_ring  non_benzene_ring.9955.jpg
#   25   non_benzene_ring  non_benzene_ring.0133.jpg
#   26   non_benzene_ring  non_benzene_ring.9975.jpg
#   27   non_benzene_ring  non_benzene_ring.0142.jpg
#   28   non_benzene_ring  non_benzene_ring.9970.jpg
#   29   non_benzene_ring  non_benzene_ring.9962.jpg
#   ..                ...                        ...
#   216      benzene_ring      benzene_ring.9800.jpg
#   217      benzene_ring      benzene_ring.0059.jpg
#   218      benzene_ring      benzene_ring.9876.jpg
#   219      benzene_ring      benzene_ring.0093.jpg
#   220      benzene_ring      benzene_ring.0048.jpg
#   221      benzene_ring      benzene_ring.0030.jpg
#   222      benzene_ring      benzene_ring.0047.jpg
#   223      benzene_ring      benzene_ring.9872.jpg
#   224      benzene_ring      benzene_ring.0004.jpg
#   225      benzene_ring      benzene_ring.9884.jpg
#   226      benzene_ring      benzene_ring.0077.jpg
#   227      benzene_ring      benzene_ring.9860.jpg
#   228      benzene_ring      benzene_ring.0031.jpg
#   229      benzene_ring      benzene_ring.0098.jpg
#   230      benzene_ring      benzene_ring.9786.jpg
#   231      benzene_ring      benzene_ring.9784.jpg
#   232      benzene_ring      benzene_ring.9835.jpg
#   233      benzene_ring      benzene_ring.9868.jpg
#   234      benzene_ring      benzene_ring.0060.jpg
#   235      benzene_ring      benzene_ring.0011.jpg
#   236      benzene_ring      benzene_ring.9892.jpg
#   237      benzene_ring      benzene_ring.9877.jpg
#   238      benzene_ring      benzene_ring.0015.jpg
#   239      benzene_ring      benzene_ring.9844.jpg
#   240      benzene_ring      benzene_ring.9807.jpg
#   241      benzene_ring      benzene_ring.9894.jpg
#   242      benzene_ring      benzene_ring.9808.jpg
#   243      benzene_ring      benzene_ring.0026.jpg
#   244      benzene_ring      benzene_ring.0082.jpg
#   245      benzene_ring      benzene_ring.0092.jpg
#
#   [246 rows x 2 columns],
#   'validation':                class                   filename
#   0   non_benzene_ring  non_benzene_ring.9952.jpg
#   1   non_benzene_ring  non_benzene_ring.0176.jpg
#   2   non_benzene_ring  non_benzene_ring.0164.jpg
#   3   non_benzene_ring  non_benzene_ring.9991.jpg
#   4   non_benzene_ring  non_benzene_ring.0165.jpg
#   5   non_benzene_ring  non_benzene_ring.0130.jpg
#   6   non_benzene_ring  non_benzene_ring.0155.jpg
#   7   non_benzene_ring  non_benzene_ring.0143.jpg
#   8   non_benzene_ring  non_benzene_ring.0137.jpg
#   9   non_benzene_ring  non_benzene_ring.9905.jpg
#   10  non_benzene_ring  non_benzene_ring.9898.jpg
#   11  non_benzene_ring  non_benzene_ring.0207.jpg
#   12  non_benzene_ring  non_benzene_ring.0139.jpg
#   13  non_benzene_ring  non_benzene_ring.0152.jpg
#   14  non_benzene_ring  non_benzene_ring.0170.jpg
#   15  non_benzene_ring  non_benzene_ring.9915.jpg
#   16  non_benzene_ring  non_benzene_ring.9942.jpg
#   17  non_benzene_ring  non_benzene_ring.9976.jpg
#   18  non_benzene_ring  non_benzene_ring.9973.jpg
#   19  non_benzene_ring  non_benzene_ring.0138.jpg
#   20  non_benzene_ring  non_benzene_ring.0163.jpg
#   21  non_benzene_ring  non_benzene_ring.0201.jpg
#   22  non_benzene_ring  non_benzene_ring.9994.jpg
#   23  non_benzene_ring  non_benzene_ring.9965.jpg
#   24  non_benzene_ring  non_benzene_ring.0109.jpg
#   25  non_benzene_ring  non_benzene_ring.0159.jpg
#   26  non_benzene_ring  non_benzene_ring.9980.jpg
#   27  non_benzene_ring  non_benzene_ring.9902.jpg
#   28  non_benzene_ring  non_benzene_ring.9928.jpg
#   29  non_benzene_ring  non_benzene_ring.0135.jpg
#   ..               ...                        ...
#   52      benzene_ring      benzene_ring.0025.jpg
#   53      benzene_ring      benzene_ring.9856.jpg
#   54      benzene_ring      benzene_ring.0045.jpg
#   55      benzene_ring      benzene_ring.9862.jpg
#   56      benzene_ring      benzene_ring.9849.jpg
#   57      benzene_ring      benzene_ring.9815.jpg
#   58      benzene_ring      benzene_ring.9873.jpg
#   59      benzene_ring      benzene_ring.0073.jpg
#   60      benzene_ring      benzene_ring.0096.jpg
#   61      benzene_ring      benzene_ring.9823.jpg
#   62      benzene_ring      benzene_ring.9797.jpg
#   63      benzene_ring      benzene_ring.0081.jpg
#   64      benzene_ring      benzene_ring.0061.jpg
#   65      benzene_ring      benzene_ring.0027.jpg
#   66      benzene_ring      benzene_ring.0024.jpg
#   67      benzene_ring      benzene_ring.9834.jpg
#   68      benzene_ring      benzene_ring.0037.jpg
#   69      benzene_ring      benzene_ring.9893.jpg
#   70      benzene_ring      benzene_ring.9821.jpg
#   71      benzene_ring      benzene_ring.0050.jpg
#   72      benzene_ring      benzene_ring.9847.jpg
#   73      benzene_ring      benzene_ring.0007.jpg
#   74      benzene_ring      benzene_ring.9789.jpg
#   75      benzene_ring      benzene_ring.0091.jpg
#   76      benzene_ring      benzene_ring.0057.jpg
#   77      benzene_ring      benzene_ring.9853.jpg
#   78      benzene_ring      benzene_ring.0072.jpg
#   79      benzene_ring      benzene_ring.9830.jpg
#   80      benzene_ring      benzene_ring.9851.jpg
#   81      benzene_ring      benzene_ring.9889.jpg
#
#   [82 rows x 2 columns],
#   'test':                class                   filename
#   0   non_benzene_ring  non_benzene_ring.9996.jpg
#   1   non_benzene_ring  non_benzene_ring.9906.jpg
#   2   non_benzene_ring  non_benzene_ring.0108.jpg
#   3   non_benzene_ring  non_benzene_ring.0149.jpg
#   4   non_benzene_ring  non_benzene_ring.0166.jpg
#   5   non_benzene_ring  non_benzene_ring.9967.jpg
#   6   non_benzene_ring  non_benzene_ring.0120.jpg
#   7   non_benzene_ring  non_benzene_ring.9912.jpg
#   8   non_benzene_ring  non_benzene_ring.9910.jpg
#   9   non_benzene_ring  non_benzene_ring.9924.jpg
#   10  non_benzene_ring  non_benzene_ring.9995.jpg
#   11  non_benzene_ring  non_benzene_ring.0212.jpg
#   12  non_benzene_ring  non_benzene_ring.9903.jpg
#   13  non_benzene_ring  non_benzene_ring.0019.jpg
#   14  non_benzene_ring  non_benzene_ring.0134.jpg
#   15  non_benzene_ring  non_benzene_ring.9985.jpg
#   16  non_benzene_ring  non_benzene_ring.9927.jpg
#   17  non_benzene_ring  non_benzene_ring.9916.jpg
#   18  non_benzene_ring  non_benzene_ring.9953.jpg
#   19  non_benzene_ring  non_benzene_ring.0204.jpg
#   20  non_benzene_ring  non_benzene_ring.0197.jpg
#   21  non_benzene_ring  non_benzene_ring.0175.jpg
#   22  non_benzene_ring  non_benzene_ring.0148.jpg
#   23  non_benzene_ring  non_benzene_ring.9984.jpg
#   24  non_benzene_ring  non_benzene_ring.0211.jpg
#   25  non_benzene_ring  non_benzene_ring.9947.jpg
#   26  non_benzene_ring  non_benzene_ring.9899.jpg
#   27  non_benzene_ring  non_benzene_ring.0173.jpg
#   28  non_benzene_ring  non_benzene_ring.0194.jpg
#   29  non_benzene_ring  non_benzene_ring.0171.jpg
#   ..               ...                        ...
#   52      benzene_ring      benzene_ring.0086.jpg
#   53      benzene_ring      benzene_ring.9886.jpg
#   54      benzene_ring      benzene_ring.0071.jpg
#   55      benzene_ring      benzene_ring.0055.jpg
#   56      benzene_ring      benzene_ring.9843.jpg
#   57      benzene_ring      benzene_ring.0065.jpg
#   58      benzene_ring      benzene_ring.9863.jpg
#   59      benzene_ring      benzene_ring.0054.jpg
#   60      benzene_ring      benzene_ring.9826.jpg
#   61      benzene_ring      benzene_ring.0094.jpg
#   62      benzene_ring      benzene_ring.0101.jpg
#   63      benzene_ring      benzene_ring.9846.jpg
#   64      benzene_ring      benzene_ring.9788.jpg
#   65      benzene_ring      benzene_ring.9793.jpg
#   66      benzene_ring      benzene_ring.0005.jpg
#   67      benzene_ring      benzene_ring.0046.jpg
#   68      benzene_ring      benzene_ring.9824.jpg
#   69      benzene_ring      benzene_ring.9790.jpg
#   70      benzene_ring      benzene_ring.9794.jpg
#   71      benzene_ring      benzene_ring.9785.jpg
#   72      benzene_ring      benzene_ring.0012.jpg
#   73      benzene_ring      benzene_ring.9804.jpg
#   74      benzene_ring      benzene_ring.9783.jpg
#   75      benzene_ring      benzene_ring.0078.jpg
#   76      benzene_ring      benzene_ring.0008.jpg
#   77      benzene_ring      benzene_ring.0033.jpg
#   78      benzene_ring      benzene_ring.9854.jpg
#   79      benzene_ring      benzene_ring.9837.jpg
#   80      benzene_ring      benzene_ring.9814.jpg
#   81      benzene_ring      benzene_ring.9828.jpg
#
#   [82 rows x 2 columns]}]
